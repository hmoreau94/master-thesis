# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data Preprocessing</a></span></li><li><span><a href="#Exploration" data-toc-modified-id="Exploration-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Exploration</a></span><ul class="toc-item"><li><span><a href="#Random-Forests" data-toc-modified-id="Random-Forests-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Random Forests</a></span><ul class="toc-item"><li><span><a href="#Principal-Component-Analysis-+-Scaling" data-toc-modified-id="Principal-Component-Analysis-+-Scaling-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Principal Component Analysis + Scaling</a></span></li><li><span><a href="#LDA" data-toc-modified-id="LDA-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>LDA</a></span></li></ul></li><li><span><a href="#Linear-SVM" data-toc-modified-id="Linear-SVM-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Linear SVM</a></span><ul class="toc-item"><li><span><a href="#PCA-+-Scaling" data-toc-modified-id="PCA-+-Scaling-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>PCA + Scaling</a></span></li><li><span><a href="#LDA" data-toc-modified-id="LDA-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>LDA</a></span></li></ul></li><li><span><a href="#Non-Linear-SVM" data-toc-modified-id="Non-Linear-SVM-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Non-Linear SVM</a></span><ul class="toc-item"><li><span><a href="#PCA-+-Scaling" data-toc-modified-id="PCA-+-Scaling-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>PCA + Scaling</a></span></li></ul></li><li><span><a href="#Gradient-Boosting" data-toc-modified-id="Gradient-Boosting-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Gradient Boosting</a></span><ul class="toc-item"><li><span><a href="#PCA-+-Scaling" data-toc-modified-id="PCA-+-Scaling-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>PCA + Scaling</a></span></li><li><span><a href="#LDA" data-toc-modified-id="LDA-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>LDA</a></span></li></ul></li><li><span><a href="#Neareast-Neighbors-classifier" data-toc-modified-id="Neareast-Neighbors-classifier-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Neareast Neighbors classifier</a></span><ul class="toc-item"><li><span><a href="#PCA-+-Scaling" data-toc-modified-id="PCA-+-Scaling-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>PCA + Scaling</a></span></li><li><span><a href="#LDA" data-toc-modified-id="LDA-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>LDA</a></span></li></ul></li><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Logistic Regression</a></span><ul class="toc-item"><li><span><a href="#PCA-+-Scaling" data-toc-modified-id="PCA-+-Scaling-2.6.1"><span class="toc-item-num">2.6.1&nbsp;&nbsp;</span>PCA + Scaling</a></span></li><li><span><a href="#LDA" data-toc-modified-id="LDA-2.6.2"><span class="toc-item-num">2.6.2&nbsp;&nbsp;</span>LDA</a></span></li></ul></li><li><span><a href="#Ridge-Regression" data-toc-modified-id="Ridge-Regression-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Ridge Regression</a></span><ul class="toc-item"><li><span><a href="#PCA-+-Scaling" data-toc-modified-id="PCA-+-Scaling-2.7.1"><span class="toc-item-num">2.7.1&nbsp;&nbsp;</span>PCA + Scaling</a></span></li><li><span><a href="#LDA" data-toc-modified-id="LDA-2.7.2"><span class="toc-item-num">2.7.2&nbsp;&nbsp;</span>LDA</a></span></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></li><li><span><a href="#Tuning-a-model" data-toc-modified-id="Tuning-a-model-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Tuning a model</a></span><ul class="toc-item"><li><span><a href="#Random-Forests" data-toc-modified-id="Random-Forests-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Random Forests</a></span></li></ul></li><li><span><a href="#Using-a-new-cross-validation-strategy" data-toc-modified-id="Using-a-new-cross-validation-strategy-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Using a new cross validation strategy</a></span><ul class="toc-item"><li><span><a href="#Importing-new-Data" data-toc-modified-id="Importing-new-Data-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Importing new Data</a></span></li><li><span><a href="#Building-a-K-Fold-with-distinct-days-in-each-Fold." data-toc-modified-id="Building-a-K-Fold-with-distinct-days-in-each-Fold.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Building a K-Fold with distinct days in each Fold.</a></span></li><li><span><a href="#Comparing-the-old-evaluation-method-to-the-new-one" data-toc-modified-id="Comparing-the-old-evaluation-method-to-the-new-one-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Comparing the old evaluation method to the new one</a></span></li><li><span><a href="#Calibrating-the-cutoff-probability" data-toc-modified-id="Calibrating-the-cutoff-probability-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Calibrating the cutoff probability</a></span></li></ul></li><li><span><a href="#A-new-exploration-(Recall-for-a-80%-precision)" data-toc-modified-id="A-new-exploration-(Recall-for-a-80%-precision)-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>A new exploration (Recall for a 80% precision)</a></span><ul class="toc-item"><li><span><a href="#Random-Forests" data-toc-modified-id="Random-Forests-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Random Forests</a></span><ul class="toc-item"><li><span><a href="#PCA" data-toc-modified-id="PCA-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>PCA</a></span></li><li><span><a href="#LDA" data-toc-modified-id="LDA-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>LDA</a></span></li></ul></li><li><span><a href="#Linear-SVM" data-toc-modified-id="Linear-SVM-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Linear SVM</a></span><ul class="toc-item"><li><span><a href="#PCA" data-toc-modified-id="PCA-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>PCA</a></span></li><li><span><a href="#LDA" data-toc-modified-id="LDA-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>LDA</a></span></li></ul></li><li><span><a href="#Non-Linear-SVM" data-toc-modified-id="Non-Linear-SVM-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Non Linear SVM</a></span><ul class="toc-item"><li><span><a href="#PCA" data-toc-modified-id="PCA-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>PCA</a></span></li><li><span><a href="#LDA" data-toc-modified-id="LDA-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>LDA</a></span></li></ul></li><li><span><a href="#Gradient-Boosting" data-toc-modified-id="Gradient-Boosting-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Gradient Boosting</a></span><ul class="toc-item"><li><span><a href="#PCA" data-toc-modified-id="PCA-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>PCA</a></span></li><li><span><a href="#LDA" data-toc-modified-id="LDA-5.4.2"><span class="toc-item-num">5.4.2&nbsp;&nbsp;</span>LDA</a></span></li></ul></li><li><span><a href="#Nearest-Neighbors" data-toc-modified-id="Nearest-Neighbors-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Nearest Neighbors</a></span><ul class="toc-item"><li><span><a href="#PCA" data-toc-modified-id="PCA-5.5.1"><span class="toc-item-num">5.5.1&nbsp;&nbsp;</span>PCA</a></span></li><li><span><a href="#LDA" data-toc-modified-id="LDA-5.5.2"><span class="toc-item-num">5.5.2&nbsp;&nbsp;</span>LDA</a></span></li></ul></li><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Logistic Regression</a></span><ul class="toc-item"><li><span><a href="#PCA" data-toc-modified-id="PCA-5.6.1"><span class="toc-item-num">5.6.1&nbsp;&nbsp;</span>PCA</a></span></li><li><span><a href="#LDA" data-toc-modified-id="LDA-5.6.2"><span class="toc-item-num">5.6.2&nbsp;&nbsp;</span>LDA</a></span></li></ul></li><li><span><a href="#Ridge-Regression" data-toc-modified-id="Ridge-Regression-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Ridge Regression</a></span><ul class="toc-item"><li><span><a href="#PCA" data-toc-modified-id="PCA-5.7.1"><span class="toc-item-num">5.7.1&nbsp;&nbsp;</span>PCA</a></span></li><li><span><a href="#LDA" data-toc-modified-id="LDA-5.7.2"><span class="toc-item-num">5.7.2&nbsp;&nbsp;</span>LDA</a></span></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></li></ul></div>

# %%
# Some important imports
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('notebook')

# Sklearn imports
import sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import train_test_split

# Own Scripts import
from scripts.utils import *
from scripts.preprocessing import *
from scripts.plot import *

# get rid of warning due to deprecated modules in sklearn
import warnings
warnings.simplefilter('ignore')
# Out:
# /Users/hmoreau/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/hmoreau/anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# ...

# %% [markdown]
# # Data Preprocessing
# We prepare our dataset such that it is usable for machine learning algorithms: this process is composed of scaling, handling missing values, converting the raw data to proper formatting...

# %%
DATA_FOLDER = './Data'
DATA_PATH = DATA_FOLDER + '/sample_11_05.xlsx'
BACKUP_PATH = DATA_FOLDER+'/sample_11_05.pk'


extracted = import_sample(DATA_PATH,BACKUP_PATH)
x_extracted, y_extracted = get_ml_data(extracted)

y = convert_to_binary_labels(y_extracted)
x_encoded = encode_categorical(x_extracted)
x = remove_features(x_encoded,verbose = True).values
# Out:
# Retrieving from ./Data/sample_11_05.pk
# The sample is composed of : 10162 vectors of dimension 291
# 	n_sick		=   2584
# 	n_healthy	=   7578
# Deleting 54 features (18.305%).

# %% [markdown]
# # Exploration
# We will now try to look at the [Receiver Operating Characteristic curve](https://en.wikipedia.org/wiki/Receiver_operating_characteristic) (ROC) of different classifiers. This curve order predictions based on their score (how sure we are that they belong to the 'sick' group), then for each prediction it will go up if the prediction is correct and right if it isn't. Therefore, the identity line ($x=y$) corresponds to a random classifier.
#
# We are interested in classifier with the steepest curve near zero as it would mean that our top predictions are very accurate (as this would mean that we could order our predictions and then handle only the top $~15\%$)
#
# We will try different models combined with different dimensionality reductions techniques (e.g. Principal Component Analysis, Linear Discriminant Analysis, Quadratic Discriminant Analysis).
#
# **Nevertheless on such plots it is very important to note that we are not using a Cross validation to draw the plot or compute the metrics**

# %% [markdown]
# ## Random Forests

# %%
# we set the percentage of top predictions that we are interested in
TOP_RATIO = 0.2
n_est_range = [10,100,1000,5000]

# %% [markdown]
# ### Principal Component Analysis + Scaling

# %%
roc_curves(n_est_range,
           lambda param: make_pipeline(
                sklearn.preprocessing.Imputer(strategy='mean'),
                preprocessing.StandardScaler(), 
                PCA(0.95),
                RandomForestClassifier(n_estimators = param, random_state = 42,n_jobs=-1)),
           x,y,
           'PCA + standard scaling + RF',
           TOP_RATIO)

# %% [markdown]
# ### LDA

# %%
roc_curves(n_est_range,
           lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),LinearDiscriminantAnalysis(),
                  RandomForestClassifier(n_estimators = param, random_state = 42,n_jobs=-1)),
           x_s,y_s,
           'LDA + RF',
           TOP_RATIO)

# %% [markdown]
# ## Linear SVM

# %% [markdown]
# ### PCA + Scaling

# %%
    pen_range = np.logspace(-2,0,4)
    roc_curves(pen_range,
               lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),
                                           preprocessing.StandardScaler(), 
                                           PCA(0.95),
                                           sklearn.calibration.CalibratedClassifierCV(sklearn.svm.LinearSVC(penalty='l1',dual=False,C=param,random_state=42, max_iter=1000))),
               x_s,y_s,
               'Linear SVM + PCA + Scaling',
               TOP_RATIO)

# %% [markdown]
# ### LDA

# %%
pen_range = np.logspace(-2,0,4)
roc_curves(pen_range,
           lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),LinearDiscriminantAnalysis(),
              sklearn.calibration.CalibratedClassifierCV(sklearn.svm.LinearSVC(penalty='l1',dual=False,C=param,random_state=42, max_iter=1000))),
           x_s,y_s,
           'LDA + Linear SVM',
           TOP_RATIO)

# %% [markdown]
# ## Non-Linear SVM
# ### PCA + Scaling

# %%
pen_range = np.logspace(0,5,4)
roc_curves(pen_range,
           lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),preprocessing.StandardScaler(), 
                  PCA(0.95),
              sklearn.calibration.CalibratedClassifierCV(sklearn.svm.SVC(C=param))),
           x_s,y_s,
           'SVM + PCA + Scaling',
           TOP_RATIO)

# %%
pen_range = np.logspace(0,1,4)
roc_curves(pen_range,
           lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),preprocessing.StandardScaler(), 
                  #PCA(0.95),
              sklearn.calibration.CalibratedClassifierCV(sklearn.svm.SVC(C=param))),
           x_s,y_s,
           'SVM + PCA + Scaling',
           TOP_RATIO)

# %% [markdown]
# ## Gradient Boosting

# %% [markdown]
# ### PCA + Scaling

# %%
roc_curves([10,100,500,1000],
           lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),preprocessing.StandardScaler(), 
                  PCA(0.95),sklearn.ensemble.GradientBoostingClassifier(n_estimators=param)),
           x_s,y_s,
           'Gradient Boosting + PCA + Scaling',
           TOP_RATIO)

# %% [markdown]
# ### LDA

# %%
roc_curves([10,100,500,1000],
           lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),LinearDiscriminantAnalysis(),sklearn.ensemble.GradientBoostingClassifier(n_estimators=param)),
           x_s,y_s,
           'Gradient Boosting + LDA',
           TOP_RATIO)

# %% [markdown]
# ## Neareast Neighbors classifier
# ### PCA + Scaling

# %%
roc_curves(np.linspace(1,100,20),
           lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),preprocessing.StandardScaler(), 
                  PCA(0.95),sklearn.neighbors.KNeighborsClassifier(n_neighbors=int(param))),
           x_s,y_s,
           'Gradient Boosting + PCA + Scaling',
           TOP_RATIO)

# %% [markdown]
# ### LDA

# %%
roc_curves(np.linspace(1,100,20),
           lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),LinearDiscriminantAnalysis(),sklearn.neighbors.KNeighborsClassifier(n_neighbors=int(param))),
           x_s,y_s,
           'Gradient Boosting + LDA',
           TOP_RATIO)

# %% [markdown]
# ## Logistic Regression
# ### PCA + Scaling

# %%
roc_curves(np.logspace(-3,2,10),
           lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),preprocessing.StandardScaler(), 
                  PCA(0.95),sklearn.linear_model.LogisticRegression(C=param, max_iter=500,n_jobs=-1)),
           x_s,y_s,
           'Logistic Regression + PCA + Scaling',
           TOP_RATIO)

# %% [markdown]
# ### LDA

# %%
roc_curves(np.logspace(-3,0,4),
           lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),LinearDiscriminantAnalysis(),sklearn.linear_model.LogisticRegression(C=param, max_iter=500,n_jobs=-1)),
           x_s,y_s,
           'Logistic Regression + LDA',
           TOP_RATIO)

# %% [markdown]
# ## Ridge Regression

# %% [markdown]
# ### PCA + Scaling

# %%
roc_curves(np.logspace(-3,2,10),
           lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),preprocessing.StandardScaler(), 
                  PCA(0.95),sklearn.calibration.CalibratedClassifierCV(sklearn.linear_model.RidgeClassifier(alpha=param))),
           x_s,y_s,
           'Ridge Regression + PCA',
           TOP_RATIO)

# %% [markdown]
# ### LDA

# %%
roc_curves(np.logspace(-3,2,10),
           lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),LinearDiscriminantAnalysis(),sklearn.calibration.CalibratedClassifierCV(sklearn.linear_model.RidgeClassifier(alpha=param))),
           x_s,y_s,
           'Ridge Regression + LDA',
           TOP_RATIO)

# %% [markdown]
# ## Conclusion
# Looking at this exploratory work we can already see that we have good results with three models:
# * Random Forests : $84.73\%$ Precision
# * SVM: $84.54\%$ Precision
# * Gradient Boosting : $83.18\%$ Precision
#
# All using PCA and with a $100\%$ Recall.

# %% [markdown]
# # Tuning a model

# %% [markdown]
# As we have seen that the PCA with an ensemble method seems to be already performing well we will try to focus on such method in order to build a more accurate model, this will involve Tuning of the ML algorithm itself but also of the data preprocessing pipeline.
#
# And again we use yet another sample of data with more `sick CPEs` (as the analysis progresses we collect more data).

# %%
DATA_FOLDER = './Data'
s_day = '16_05'
DATA_PATH = DATA_FOLDER + '/sample_'+s_day+'.xlsx'
BACKUP_PATH = DATA_FOLDER+'/sample_'+s_day+'.pk'


extracted = import_sample(DATA_PATH,BACKUP_PATH)
x_extracted, y_extracted = get_ml_data(extracted)

y = convert_to_binary_labels(y_extracted)
x_encoded = encode_categorical(x_extracted)
x = remove_features(x_encoded,verbose = True).values
# Out:
# Retrieving from ./Data/sample_16_05.pk
# The sample is composed of : 10972 vectors of dimension 291
# 	n_sick		=   3057
# 	n_healthy	=   7915
# Deleting 54 features (18.305%).

# %% [markdown]
# ## Random Forests

# %%
# we set the percentage of top predictions that we are interested in
TOP_RATIO = 0.2
n_est_range = [1000]
roc_curves(n_est_range,
           lambda param: make_pipeline(
                sklearn.preprocessing.Imputer(strategy='mean'),
                preprocessing.StandardScaler(), 
                PCA(0.95),
                RandomForestClassifier(n_estimators = param, random_state = 42,n_jobs=-1)),
           x_s,y_s,
           'PCA + standard scaling + RF',
           TOP_RATIO)

# %% [markdown]
# It would be interesting to look at whether our model holds even if trained on days that are a couple of days in the past compared to the testing data. (This will give us information regarding how frequently we need to train the model but also to see whether the data has a lot of seasonality or not).
#
# In order to do that we will create a training dataset and an hold-out set. To build this Hold-out set we will keep 3 days of data in the hold out and will look at the accuracy on this hold out set for different gaps between training and testing

# %%
def get_performance_gap_hold_out(extracted,ho_n_days,gap_n_days,clf_pipeline,top_ratio = 0.2):
    # Compute the dates we wish to work with
    dates = extracted['day_0'].unique()
    dates.sort()
    ho_days = dates[-(1+ho_n_days):-1]
    dataset_days = dates[:len(dates)-(ho_n_days+gap_n_days+1)]

    # get the two datasets
    dataset = extracted[extracted['day_0'].isin(dataset_days)]
    hold_out = extracted[extracted['day_0'].isin(ho_days)]
    print('Hold Out population = {}\nTraining Population = {}'.format(len(hold_out),len(dataset)))

    # prepare these datasets
    x_extracted, y_extracted = get_ml_data(dataset)
    y = convert_to_binary_labels(y_extracted)
    x_encoded = encode_categorical(x_extracted)
    x = remove_features(x_encoded,verbose = False).values
    x_s,y_s = get_balanced_classes(x,y)
    clf_pipeline.fit(x_s,y_s)

    x_extracted_ho, y_extracted_ho = get_ml_data(hold_out)
    y_ho = convert_to_binary_labels(y_extracted_ho)
    x_encoded_ho = encode_categorical(x_extracted_ho)
    x_ho = remove_features(x_encoded_ho,verbose = False).values
    x_s_ho,y_s_ho = get_balanced_classes(x_ho,y_ho)
    
    preds = clf_pipeline.predict_proba(x_s_ho)
    return get_metrics(preds,y_s_ho,top_ratio)

# %%
clf = make_pipeline(
    sklearn.preprocessing.Imputer(strategy='mean'),
    preprocessing.StandardScaler(), 
    PCA(0.95),
    RandomForestClassifier(n_estimators = 10, random_state = 42,n_jobs=-1))

# %%
ho_n_days=2
gap_n_days=0
clf_pipeline=clf

no_entirely_healthy_day = sick_per_day[sick_per_day['sick'] > 0].index
extracted = extracted[extracted['day_0'].isin(no_entirely_healthy_day)]

# Compute the dates we wish to work with
dates = extracted['day_0'].unique()
dates.sort()
ho_days = dates[-(1+ho_n_days):-1]
dataset_days = dates[:len(dates)-(ho_n_days+gap_n_days+1)]

# get the two datasets
dataset = extracted[extracted['day_0'].isin(dataset_days)]
hold_out = extracted[extracted['day_0'].isin(ho_days)]
print('Hold Out population = {}\nTraining Population = {}'.format(len(hold_out),len(dataset)))

# prepare these datasets
x_extracted, y_extracted = get_ml_data(dataset)
y = convert_to_binary_labels(y_extracted)
x_encoded = encode_categorical(x_extracted)
x = remove_features(x_encoded,verbose = False).values
x_s,y_s = get_balanced_classes(x,y)


x_extracted_ho, y_extracted_ho = get_ml_data(hold_out)
y_ho = convert_to_binary_labels(y_extracted_ho)
x_encoded_ho = encode_categorical(x_extracted_ho)
x_ho = remove_features(x_encoded_ho,verbose = False).values
x_s_ho,y_s_ho = get_balanced_classes(x_ho,y_ho)
# Out:
# Hold Out population = 782
# Training Population = 9876

# %%
# we set the percentage of top predictions that we are interested in
TOP_RATIO = 0.2
n_est_range = [1000]
roc_curves(n_est_range,
           lambda param: make_pipeline(
                sklearn.preprocessing.Imputer(strategy='mean'),
                preprocessing.StandardScaler(), 
                PCA(0.95),
                RandomForestClassifier(n_estimators = param, random_state = 42,n_jobs=-1)),
           x_s,y_s,
           'PCA + standard scaling + RF',
           TOP_RATIO)

# %%
clf_pipeline.fit(x_s,y_s)
preds = clf_pipeline.predict_proba(x_s_ho)

# %%
# P,R,F1 on the top 40%
get_metrics(preds,y_s_ho,0.4)
# Out:
# (49.693251533742334, 100.0, 66.393442622950829)

# %% [markdown]
# Unfortunately we realize that doing a cross validation on the full dataset wasn't a good idea as we may have overfited certain dates, which is why we will now evaluate models based on a K-fold where the train set and test set always consist of distinct dates.

# %% [markdown]
# # Using a new cross validation strategy

# %% [markdown]
# ## Importing new Data

# %%
DATA_FOLDER = './Data'
s_day = '22_05'
DATA_PATH = DATA_FOLDER + '/sample_'+s_day+'.xlsx'
BACKUP_PATH = DATA_FOLDER+'/sample_'+s_day+'.pk'


extracted = import_sample(DATA_PATH,BACKUP_PATH)
x_extracted, y_extracted = get_ml_data(extracted)

y = convert_to_binary_labels(y_extracted)
x_encoded = encode_categorical(x_extracted)
x = remove_features(x_encoded,verbose = True).values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0a7d37c68576> in <module>()
#       5
#       6
# ----> 7 extracted = import_sample(DATA_PATH,BACKUP_PATH)
#       8 x_extracted, y_extracted = get_ml_data(extracted)
#       9
#
# NameError: name 'import_sample' is not defined

# %% [markdown]
# ## Building a K-Fold with distinct days in each Fold.

# %% [markdown]
# We will now use a K-fold technique such that each fold contains distinct dates and we can evaluate properly the performance of our models.

# %%
## param 
k = 5
balanced = True
shuffle = True
dates = extracted['day_0'].values

splits =  distinct_date_split(x,y,dates,k=2)
splits
# Out:
# [(array([ 5162, 14219, 11667, ...,  1595,  8516,  9756]),
#   array([10464,   181,  7016, ...,  9911,  1437, 10291])),
#  (array([11086,  4233,  4188, ...,  2436,   976,  2291]),
#   array([ 1749,  1682, 13990, ...,  7042,  9297,  9309]))]

# %%
clf = make_pipeline(
    sklearn.preprocessing.Imputer(strategy='mean'),
    LinearDiscriminantAnalysis(),
    RandomForestClassifier(n_estimators = 1000, random_state = 42,n_jobs=-1))

P,R,F1 = get_cross_validated_metrics(clf,0.2,x,y,dates=extracted['day_0'].values,dates_fold=True,cv=5)
print('P = {:.3f}%, R = {:.3f}%, F1 = {:.3f}%'.format(P,R,F1))
# Out:
# P = 38.681%, R = 100.000%, F1 = 55.685%

# %% [markdown]
# Also now the ROC curve might not be as insightful as we are experiencing a significant drop in precision. Therefore we may now want to look at the precision for different levels of Recall.

# %% [markdown]
# ## Comparing the old evaluation method to the new one

# %% [markdown]
# Without distinct dates Cross Validation

# %%
dates = extracted['day_0'].values
TOP_RATIO = 0.2
n_est_range = [1000]
roc_curves(n_est_range,
           lambda param: make_pipeline(
                sklearn.preprocessing.Imputer(strategy='mean'),
                preprocessing.StandardScaler(), 
                PCA(0.95),
                RandomForestClassifier(n_estimators = param, random_state = 42,n_jobs=-1)),
           x,y,
           'PCA + standard scaling + RF',
           TOP_RATIO,dates=dates,distinct_date=False)

# %% [markdown]
# Now that we use the Cross validation built earlier to have distinct dates in the training and testing set.

# %%
# we set the percentage of top predictions that we are interested in
TOP_RATIO = 0.2
n_est_range = [1000]
roc_curves(n_est_range,
           lambda param: make_pipeline(
                sklearn.preprocessing.Imputer(strategy='mean'),
                preprocessing.StandardScaler(), 
                PCA(0.95),
                RandomForestClassifier(n_estimators = param, random_state = 42,n_jobs=-1)),
           x,y,
           'PCA + standard scaling + RF',
           TOP_RATIO,dates=dates,distinct_date=True,cv=10)

# %%
# Let's look at the number of sick CPEs per day
df = pd.DataFrame()
df['date'] = dates
df['sick'] = y
df.groupby('date').sum().mean()
# Out:
# sick    103.694444
# dtype: float64

# %% [markdown]
# It is important to note that P is the **Precision on the top 20% prediction**, it shows the number of true positive out of all the positives.
#
# The previous analysis shows that we have on average 103 sick routers every day. One should keep in mind that we are working on subsample of the dataset that contains all the sick routers but only a small fraction of the healthy ones. From our SQL data collection there are approximately 500k distinct routers that we collect every day.
#
# Therefore if an operator would have to check randomly a router from the full network he would have a probability of $\approx \frac{100}{500000} = 0.02\%$ to find a sick CPE. If he checks from the subset of routers we declare as being sick he now has a probability of $\approx 49\%$ to find a sick one.
#
# That is, to our belief a significant improvement.

# %% [markdown]
# ## Calibrating the cutoff probability
# for now we are simply considering our top $20\%$ predictions based on their probability to belong to the sick class and we would like to have a ```cutoff_proba``` instead to select only the predictions that we are the most sure about.
#
# Therefore we will look at the evolution of the precision and recall for different models such that we can encapsulate the trade-off between the two. Either we catch more sick CPEs but have to drop the precision of our prediction (="the number of CPEs that we declare as being sick and that are indeed sick") or we will catch less but will be (more) sure about the ones we declare as being sick.

# %% [markdown]
# In order to evaluate our models we will look at the highest level of recall that can be achieved for a desired precision. This will in vulgarized terms tell us the proportion of CPEs that we can achieve depending on how sure we wish to be of our prediction.
#
# We have to use such evaluation as the true precision-recall curve cannot be approximated in an unbiased manner using a cross validation.

# %%
clf = make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),
                preprocessing.StandardScaler(), 
                PCA(0.95),
                RandomForestClassifier(n_estimators = 10, random_state = 42,n_jobs=-1))

# %%
n_est_range = [10,20]
pipeline = lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),
                preprocessing.StandardScaler(), 
                PCA(0.95),
                RandomForestClassifier(n_estimators = param, random_state = 42,n_jobs=-1))
precision_recall_curves(n_est_range,pipeline,x,y,'PCA RF',[0.8,0.9],dates)

# %% [markdown]
# Using this technique we can now do the same work of exploration that was done before-hand to compare models and get a model that will allow us to get a the bets recall with an 80% precision score on the 'sick' class.

# %% [markdown]
# # A new exploration (Recall for a 80% precision)

# %% [markdown]
# We will try to approach the problem in the same manner than we did.

# %% [markdown]
# ## Random Forests

# %% [markdown]
# ### PCA

# %%
params = [100,1000,5000]
pipeline = lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),
                preprocessing.StandardScaler(), 
                PCA(0.95),
                RandomForestClassifier(n_estimators = param, random_state = 42,n_jobs=-1))
precision_recall_curves(params,pipeline,x,y,'PCA RF',[0.8,0.9],dates)

# %% [markdown]
# ### LDA

# %%
params = [100,1000,5000]
pipeline = lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),
                LinearDiscriminantAnalysis(),
                RandomForestClassifier(n_estimators = param, random_state = 42,n_jobs=-1))
precision_recall_curves(params,pipeline,x,y,'LDA RF',[0.8,0.9],dates)

# %% [markdown]
# ## Linear SVM

# %% [markdown]
# ### PCA

# %%
#params = np.logspace(-2,0,4)
params = np.logspace(-3,0,10)
pipeline = lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),
                                       preprocessing.StandardScaler(), 
                                       PCA(0.95),
                                       sklearn.calibration.CalibratedClassifierCV(sklearn.svm.LinearSVC(penalty='l1',dual=False,C=param,random_state=42, max_iter=1000)))
precision_recall_curves(params,pipeline,x,y,'Linear SVM + PCA + Scaling',[0.8,0.9],dates)

# %% [markdown]
# Linear SVM + PCA :
# * param = 0.01 [10.75%,2.38%]
# * param = 0.215 [10.61%,4.50%]

# %% [markdown]
# ### LDA

# %%
pipeline = lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),
                                       LinearDiscriminantAnalysis(),
                                       sklearn.calibration.CalibratedClassifierCV(sklearn.svm.LinearSVC(penalty='l1',dual=False,C=param,random_state=42, max_iter=1000)))
precision_recall_curves(params,pipeline,x,y,'Linear SVM + LDA',[0.8,0.9],dates)

# %% [markdown]
# Linear SVM + LDA :
# * param = 0.005 [10.94%,2.40%]
# * param = 0.1 [11.24%,1.72%]

# %% [markdown]
# ## Non Linear SVM

# %% [markdown]
# ### PCA

# %%
params = np.logspace(-1,0,4)
pipeline = lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),preprocessing.StandardScaler(), 
                  PCA(0.95),
              sklearn.calibration.CalibratedClassifierCV(sklearn.svm.SVC(C=param)))
precision_recall_curves(params,pipeline,x,y,'SVM + PCA + Scaling',[0.8,0.9],dates)

# %% [markdown]
# ### LDA

# %%
pipeline = lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),
                                       LinearDiscriminantAnalysis(),
              sklearn.calibration.CalibratedClassifierCV(sklearn.svm.SVC(C=param)))
precision_recall_curves(params,pipeline,x,y,'SVM + LDA',[0.8,0.9],dates)

# %% [markdown]
# ## Gradient Boosting

# %% [markdown]
# ### PCA

# %%
params = [500,1000,5000]
pipeline = lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),preprocessing.StandardScaler(), 
                  PCA(0.95),sklearn.ensemble.GradientBoostingClassifier(n_estimators=param))
precision_recall_curves(params,pipeline,x,y,'GB + PCA + Scaling',[0.8,0.9],dates)

# %% [markdown]
# Gradient Boosting + PCA:
# * param = 500 [12.03%,4.45%]

# %% [markdown]
# ### LDA

# %%
pipeline = lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),LinearDiscriminantAnalysis(),
                                       sklearn.ensemble.GradientBoostingClassifier(n_estimators=param))
precision_recall_curves(params,pipeline,x,y,'GB + LDA',[0.8,0.9],dates)

# %% [markdown]
# ## Nearest Neighbors

# %% [markdown]
# ### PCA

# %%
params = np.linspace(1,100,10)
pipeline = lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),preprocessing.StandardScaler(), 
                  PCA(0.95),sklearn.neighbors.KNeighborsClassifier(n_neighbors=int(param)))
precision_recall_curves(params,pipeline,x,y,'NN + PCA',[0.8,0.9],dates)

# %% [markdown]
# ### LDA

# %%
pipeline = lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),LinearDiscriminantAnalysis()
                                       ,sklearn.neighbors.KNeighborsClassifier(n_neighbors=int(param)))
precision_recall_curves(params,pipeline,x,y,'NN + LDA',[0.8,0.9],dates)

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ### PCA

# %%
params = np.logspace(-3,2,20)
pipeline = lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),preprocessing.StandardScaler(), 
                  PCA(0.95),sklearn.linear_model.LogisticRegression(C=param, max_iter=500,n_jobs=-1))
precision_recall_curves(params,pipeline,x,y,'Logistic + PCA',[0.8,0.9],dates)

# %% [markdown]
# LogReg + PCA:
# * Param = 8.859 [13.02%,2.70%]
# * Param = 0.021 [12.62%,3.16%]
#
# A lot of models above 10%

# %% [markdown]
# ### LDA

# %%
pipeline = lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),LinearDiscriminantAnalysis(),
                                       sklearn.linear_model.LogisticRegression(C=param, max_iter=500,n_jobs=-1))
precision_recall_curves(params,pipeline,x,y,'Logistic + LDA',[0.8,0.9],dates)

# %% [markdown]
# LogReg + LDA:
# * param = 0.167 [12.69%,2,24%] (but the curve is not really monotonic)

# %% [markdown]
# ## Ridge Regression

# %% [markdown]
# ### PCA

# %%
params = np.logspace(-3,2,10)
pipeline = lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),preprocessing.StandardScaler(), 
                  PCA(0.95),
                sklearn.calibration.CalibratedClassifierCV(sklearn.linear_model.RidgeClassifier(alpha=param)))
precision_recall_curves(params,pipeline,x,y,'Ridge + PCA',[0.8,0.9],dates)

# %% [markdown]
# Ridge + PCA:
# * param = 0.001 [11.62%,5.40%] (and a very high precision at low recall)

# %% [markdown]
# ### LDA

# %%
pipeline = lambda param: make_pipeline(sklearn.preprocessing.Imputer(strategy='mean'),LinearDiscriminantAnalysis(),
                sklearn.calibration.CalibratedClassifierCV(sklearn.linear_model.RidgeClassifier(alpha=param)))
precision_recall_curves(params,pipeline,x,y,'Ridge + LDA',[0.8,0.9],dates)

# %% [markdown]
# Ridge + LDA:
# * param = 0.004 [12.41%,1.50%]

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **NB: While the values that are displayed in the title of the plots can be trusted as they are Cross validated, the plots are only here as a more graphical interpretation of the results and should not be trusted blindly**.
#
# Nevertheless, we can explain the characteristics of the graph that we wish to monitor:
# * We would ideally like a non increasing curve (otherwise we wouldn't be more confident of predictions with a high probability of belonging to the 'sick' class.
# * Also we would like to have a larger area under the curve on the leftmost part of the curve (which will also mean that we have a higher precision per recall)
#
# ```
# Ordered by performance we should investigate:
# 1. LogReg + PCA (A lot of models above 10%):
#     * Param = 8.859 [13.02%,2.70%]
#     * Param = 0.021 [12.62%,3.16%]
# 2. Ridge + PCA:
#     * param = 0.001 [11.62%,5.40%] (and a very high precision at low recall)
# 3. Ridge + LDA:
#     * param = 0.004 [12.41%,1.50%]
# 4. Gradient Boosting + PCA:
#     * param = 500   [12.03%,4.45%]
#
# And some others :
# 1. Linear SVM + PCA :
#     * param = 0.01  [10.75%,2.38%]
#     * param = 0.215 [10.61%,4.50%]
# 2. Linear SVM + LDA :
#     * param = 0.005 [10.94%,2.40%]
#     * param = 0.1   [11.24%,1.72%]
# 3. LogReg + LDA:
#     * param = 0.167 [12.69%,2,24%] (but the curve is not really monotonic)
# ```

# %%
y_extracted.unique()
# Out:
# [NaN, internet.noconnection.start, internet.services.connectapp.start, internet.interruption.start, internet.wifree.start, internet.performance.start, tv.check, internet.installation.powerline.start]
# Categories (7, object): [internet.noconnection.start, internet.services.connectapp.start, internet.interruption.start, internet.wifree.start, internet.performance.start, tv.check, internet.installation.powerline.start]
